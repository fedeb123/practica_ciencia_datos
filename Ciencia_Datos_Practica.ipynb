# %%
import numpy as np
import pandas as pd

dataset = pd.read_csv("./bank.csv")

dataset
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: partially initialized module 'pandas' from 'c:\Users\feder\Documents\practica_ciencia_datos\venv\Lib\site-packages\pandas\__init__.py' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ../../../pip-build-env-4dpcnm37/overlay/Lib/site-packages/numpy/__init__.cython-30.pxd:1009, in numpy.import_array()
# -> 1009 'Could not get source, probably due dynamically evaluated source code.'
#
# SystemError: <built-in function __import__> returned a result with an exception set
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ...
